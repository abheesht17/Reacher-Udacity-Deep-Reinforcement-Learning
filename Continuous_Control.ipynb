# %% [markdown]
# # Continuous Control
#
# ---
#
# You are welcome to use this coding environment to train your agent for the project.  Follow the instructions below to get started!
#
# ### 1. Start the Environment
#
# Run the next code cell to install a few packages.  This line will take a few minutes to run!

# %%
# !pip -q install ./python
# Out:
# tensorflow 1.7.1 has requirement numpy>=1.13.3, but you'll have numpy 1.12.1 which is incompatible.
# ipython 6.5.0 has requirement prompt-toolkit<2.0.0,>=1.0.15, but you'll have prompt-toolkit 3.0.5 which is incompatible.

# %% [markdown]
# The environments corresponding to both versions of the environment are already saved in the Workspace and can be accessed at the file paths provided below.
#
# Please select one of the two options below for loading the environment.

# %%
from unityagents import UnityEnvironment
import numpy as np

# select this option to load version 1 (with a single agent) of the environment
#env = UnityEnvironment(file_name='/data/Reacher_One_Linux_NoVis/Reacher_One_Linux_NoVis.x86_64')

# select this option to load version 2 (with 20 agents) of the environment
env = UnityEnvironment(file_name='/data/Reacher_Linux_NoVis/Reacher.x86_64')
# Out:
# INFO:unityagents:
# 'Academy' started successfully!
# Unity Academy name: Academy
#         Number of Brains: 1
#         Number of External Brains : 1
#         Lesson number : 0
#         Reset Parameters :
# 		goal_speed -> 1.0
# 		goal_size -> 5.0
# Unity brain name: ReacherBrain
#         Number of Visual Observations (per agent): 0
#         Vector Observation space type: continuous
#         Vector Observation space size (per agent): 33
#         Number of stacked Vector Observation: 1
#         Vector Action space type: continuous
#         Vector Action space size (per agent): 4
#         Vector Action descriptions: , , ,

# %% [markdown]
# Environments contain **_brains_** which are responsible for deciding the actions of their associated agents. Here we check for the first brain available, and set it as the default brain we will be controlling from Python.

# %%
# get the default brain
brain_name = env.brain_names[0]
brain = env.brains[brain_name]

# %% [markdown]
# ### 2. Examine the State and Action Spaces
#
# Run the code cell below to print some information about the environment.

# %%
# reset the environment
env_info = env.reset(train_mode=True)[brain_name]

# number of agents
num_agents = len(env_info.agents)
print('Number of agents:', num_agents)

# size of each action
action_size = brain.vector_action_space_size
print('Size of each action:', action_size)

# examine the state space 
states = env_info.vector_observations
state_size = states.shape[1]
print('There are {} agents. Each observes a state with length: {}'.format(states.shape[0], state_size))
print('The state for the first agent looks like:', states[0])
#print('The state for the second agent looks like:', states[1])
# Out:
# Number of agents: 20
# Size of each action: 4
# There are 20 agents. Each observes a state with length: 33
# The state for the first agent looks like: [  0.00000000e+00  -4.00000000e+00   0.00000000e+00   1.00000000e+00
#   -0.00000000e+00  -0.00000000e+00  -4.37113883e-08   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00  -1.00000000e+01   0.00000000e+00
#    1.00000000e+00  -0.00000000e+00  -0.00000000e+00  -4.37113883e-08
#    0.00000000e+00   0.00000000e+00   0.00000000e+00   0.00000000e+00
#    0.00000000e+00   0.00000000e+00   5.75471878e+00  -1.00000000e+00
#    5.55726624e+00   0.00000000e+00   1.00000000e+00   0.00000000e+00
#   -1.68164849e-01]

# %% [markdown]
# ### 3. Take Random Actions in the Environment
#
# In the next code cell, you will learn how to use the Python API to control the agent and receive feedback from the environment.
#
# Note that **in this coding environment, you will not be able to watch the agents while they are training**, and you should set `train_mode=True` to restart the environment.

# %%
env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
states = env_info.vector_observations                  # get the current state (for each agent)
scores = np.zeros(num_agents)                          # initialize the score (for each agent)
while True:
    actions = np.random.randn(num_agents, action_size) # select an action (for each agent)
    actions = np.clip(actions, -1, 1)                  # all actions between -1 and 1
    env_info = env.step(actions)[brain_name]           # send all actions to tne environment
    next_states = env_info.vector_observations         # get next state (for each agent)
    rewards = env_info.rewards                         # get reward (for each agent)
    dones = env_info.local_done                        # see if episode finished
    scores += env_info.rewards                         # update the score (for each agent)
    states = next_states                               # roll over states to next time step
    if np.any(dones):                                  # exit loop if episode finished
        break
print('Total score (averaged over agents) this episode: {}'.format(np.mean(scores)))
# Out:
# Total score (averaged over agents) this episode: 0.08149999817833305

# %% [markdown]
# ### 4. It's Your Turn!
#
# Now it's your turn to train your own agent to solve the environment!  A few **important notes**:
# - When training the environment, set `train_mode=True`, so that the line for resetting the environment looks like the following:
# ```python
# env_info = env.reset(train_mode=True)[brain_name]
# ```
# - To structure your work, you're welcome to work directly in this Jupyter notebook, or you might like to start over with a new file!  You can see the list of files in the workspace by clicking on **_Jupyter_** in the top left corner of the notebook.
# - In this coding environment, you will not be able to watch the agents while they are training.  However, **_after training the agents_**, you can download the saved model weights to watch the agents on your own machine!

# %%
import torch
import torch.nn.functional as F
import torch.nn as nn

from collections import deque
import random
import torch.optim as optim
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
print(device)
#action_space: sin(theta),cos(theta) of both joints. Hence, size=4
BUFFER_SIZE=100000
BATCH_SIZE=128
GAMMA=0.99
TAU=0.001

LRactor=5e-4
LRcritic=5e-4
UPDATE_EVERY=1

#add seed to classes
# Out:
# cpu

# %%
import torch.nn
class Actor(nn.Module):
    def __init__(self,state_size=33, action_size=4,seed=0):
        super(Actor, self).__init__()
        self.state_size=state_size
        self.action_size=action_size
        self.fc1=nn.Linear(self.state_size,128)
        self.bn1 = nn.BatchNorm1d(128)

        self.fc2=nn.Linear(128,128)
        self.fc3=nn.Linear(128,self.action_size)
        self.seed=torch.manual_seed(seed)
    def forward(self, x):
        #return F.tanh(self.fc3(F.relu(self.fc2(self.bn1(F.relu(self.fc1(x)))))))
        x=F.relu(self.fc1(x))
        #x=self.bn1(x)
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return F.tanh(x)

state=np.array([  0.00000000e+00,-4.00000000e+00 ,  0.00000000e+00  , 1.00000000e+00,
  -0.00000000e+00 , -0.00000000e+00 , -4.37113883e-08 ,  0.00000000e+00,
   0.00000000e+00 ,  0.00000000e+00  , 0.00000000e+00  , 0.00000000e+00,
   0.00000000e+00 ,  0.00000000e+00 , -1.00000000e+01 ,  0.00000000e+00,
   1.00000000e+00 , -0.00000000e+00 , -0.00000000e+00 , -4.37113883e-08,
   0.00000000e+00 ,  0.00000000e+00  , 0.00000000e+00 ,  0.00000000e+00,
   0.00000000e+00 ,  0.00000000e+00  , 7.90150833e+00 , -1.00000000e+00,
   1.25147629e+00 ,  0.00000000e+00  , 1.00000000e+00 ,  0.00000000e+00,
  -5.22214413e-01])

# %%
class Critic(nn.Module):
    def __init__(self, state_size=33,action_size=4,seed=0):
        super(Critic, self).__init__()
        self.state_size=state_size
        self.action_size=action_size
        self.fc1=nn.Linear(self.state_size,128)
        self.bn1 = nn.BatchNorm1d(128)

        self.fc2=nn.Linear(128+self.action_size,128)
        self.fc3=nn.Linear(128,1)
        self.seed=torch.manual_seed(seed)
    def forward(self,state,action):
        x=F.relu(self.fc1(state))
        #x=self.bn1(x)
        #print(x.shape)
        action=action.view(BATCH_SIZE,-1)
        #print(action.shape)
        x=torch.cat([x,action],1)
        x=F.relu(self.fc2(x))
        x=self.fc3(x)
        return x

# %%
class Memory:
    def __init__(self,seed=0):
        self.memory=deque(maxlen=BUFFER_SIZE)
        self.seed=torch.manual_seed(seed)
    def add(self,state, action, reward,next_state,done):
        self.memory.append([state,action,reward,next_state,done])
    def sample(self,batch_size=BATCH_SIZE):
        experiences=random.sample(self.memory, k=batch_size)
        states=[]
        actions=[]
        rewards=[]
        next_states=[]
        dones=[]
        for i in experiences:
            states.append(i[0])
            actions.append(i[1])
            rewards.append(i[2])
            next_states.append(i[3])
            dones.append(i[4])
        return states, actions,rewards,next_states, dones
    def __len__(self):
        return len(self.memory)

# %%
import copy
class OUNoise(object):
    def __init__(self, action_space=4, mu=0.0, theta=0.15, max_sigma=0.3, min_sigma=0.3, decay_period=100000,seed=0):
        self.mu           = mu
        self.theta        = theta
        self.sigma        = max_sigma
        self.max_sigma    = max_sigma
        self.min_sigma    = min_sigma
        self.decay_period = decay_period
        self.action_dim   = 4
        self.low          = -1
        self.high         = 1
        self.seed=torch.manual_seed(seed)
        self.reset()
        
    def reset(self):
        self.state = np.ones(self.action_dim) * self.mu
        
    def evolve_state(self):
        x  = self.state
        dx = self.theta * (self.mu - x) + self.sigma * np.random.randn(self.action_dim)
        self.state = x + dx
        return self.state
    
    def get_action(self, action, t=0):
        ou_state = self.evolve_state()
        self.sigma = self.max_sigma - (self.max_sigma - self.min_sigma) * min(1.0, t / self.decay_period)
        return np.clip(action + ou_state, self.low, self.high)

# %%
class DDPG:
    def __init__(self,state_size=33,action_size=4,seed=0):
        self.state_size=state_size
        self.action_size=action_size
        
        self.actorlocal=Actor(state_size,action_size).to(device)
        self.actortarget=Actor(state_size,action_size).to(device)
        
        self.criticlocal=Critic(state_size,action_size).to(device)
        self.critictarget=Critic(state_size,action_size).to(device)
        
        self.memory=Memory()
        
        self.noise=OUNoise(action_space=action_size)
        
        self.t_step=0
        self.optimizeractor=optim.Adam(self.actorlocal.parameters(),lr=LRactor)
        self.optimizercritic=optim.Adam(self.criticlocal.parameters(),lr=LRcritic)
        self.critic_criterion  = nn.MSELoss()
        self.seed=torch.manual_seed(seed)
        self.hard_copy_weights(self.actortarget, self.actorlocal)
        self.hard_copy_weights(self.critictarget, self.criticlocal)


    
    def hard_copy_weights(self, target, source):
        """ copy weights from source to target network (part of initialization)"""
        for target_param, param in zip(target.parameters(), source.parameters()):
            target_param.data.copy_(param.data)
    
    def step(self,state, action,reward,next_state, done):
        self.memory.add(state, action,reward,next_state,done)
        self.t_step=(self.t_step+1)%UPDATE_EVERY
        if(self.t_step==0):
            if(len(self.memory)>=BATCH_SIZE):
                experiences=self.memory.sample()
                self.learn(experiences)
    
    def act(self,state):
        state = torch.from_numpy(state).float().unsqueeze(0).to(device)
        action = self.actorlocal(state)
        action = action.cpu().detach().numpy()
        """if True:
            action += self.noise.sample()"""
        #return np.clip(action, -1, 1)
        return action
        
        
    
    def learn(self,experiences):
        states, actions, rewards, next_states, dones = experiences
        states = torch.FloatTensor(states).to(device)
        actions = torch.FloatTensor(actions).to(device)
        rewards = torch.FloatTensor(rewards).to(device)
        next_states = torch.FloatTensor(next_states).to(device)
        dones=torch.FloatTensor(dones).to(device)
    
        # Critic loss        
        Qvals = self.criticlocal(states, actions)
        next_actions = self.actortarget(next_states)
        next_Q = self.critictarget(next_states, next_actions.detach())
        rewards=rewards.view(BATCH_SIZE,1)
        dones=dones.view(BATCH_SIZE,1)
        Qprime = rewards + (GAMMA * next_Q *(1-dones))
        #print(Qprime)
        #print(Qvals)
        critic_loss = self.critic_criterion(Qvals, Qprime.detach())

        # Actor loss
        policy_loss = -self.critictarget(states, self.actorlocal(states)).mean()
        
        # update networks
        self.optimizeractor.zero_grad()
        policy_loss.backward()
        self.optimizeractor.step()

        self.optimizercritic.zero_grad()
        critic_loss.backward() 
        self.optimizercritic.step()

        # update target networks 
        for target_param, param in zip(self.actortarget.parameters(), self.actorlocal.parameters()):
            target_param.data.copy_(param.data * TAU + target_param.data * (1.0 - TAU))
       
        for target_param, param in zip(self.critictarget.parameters(), self.criticlocal.parameters()):
            target_param.data.copy_(param.data * TAU + target_param.data * (1.0 - TAU))

# %%
num_episodes=1000
#eps=1
#eps_decay=0.995
#eps_final=0.01
agent=DDPG()
noise=OUNoise()
scores_lst=[]
scores_window=deque(maxlen=100)
for i in range(num_episodes+1):    
    env_info = env.reset(train_mode=True)[brain_name]      # reset the environment    
    states = env_info.vector_observations                  # get the current state (for each agent)
    scores = np.zeros(num_agents)
    
    t_step=0
    agt_ctr=-1
    while True:
        #actions=[]
    
        """for j in range(20):
            action=agent.act(states[j])
            action=noise.get_action(action,t_step)
            actions.append(action)"""
        actions=[noise.get_action(agent.act(states[j]),t_step) for j in range(20)]
        env_info = env.step(actions)[brain_name]           
        next_states = env_info.vector_observations         
        rewards = env_info.rewards                         
        dones = env_info.local_done
        if(t_step%2==0):
            agt_ctr=(agt_ctr+1)%20
            agent.step(states[agt_ctr],actions[agt_ctr],rewards[agt_ctr],next_states[agt_ctr],dones[agt_ctr])
        for j in range(20):
            if(j!=agt_ctr):
                agent.memory.add(states[j],actions[j], rewards[j],next_states[j],dones[j])        
        scores += env_info.rewards
        states = next_states                               
        t_step+=1
        if np.any(dones):                                  
            break
    scores_lst.append(scores)
    scores_window.append(scores)
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(i, np.mean(scores_window)), end="")
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(i, np.mean(scores_window)))
    if np.mean(scores_window)>30.0:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i, np.mean(scores_window)))
        torch.save(agent.actorlocal.state_dict(), 'checkpointactor.pth')
        torch.save(agent.criticlocal.state_dict(),'checkpointcritic.pth')
        break
# Out:
# Episode 0	Average Score: 0.86
# Episode 1	Average Score: 1.02
# Episode 2	Average Score: 0.99
# Episode 3	Average Score: 0.98
# Episode 4	Average Score: 1.00
# Episode 5	Average Score: 0.97
# Episode 6	Average Score: 0.93
# Episode 7	Average Score: 0.86
# Episode 8	Average Score: 0.84
# Episode 9	Average Score: 0.83
# Episode 10	Average Score: 0.82
# Episode 11	Average Score: 0.80
# Episode 12	Average Score: 0.80
# Episode 13	Average Score: 0.82
# Episode 14	Average Score: 0.85
# Episode 15	Average Score: 0.88
# Episode 16	Average Score: 0.90
# Episode 17	Average Score: 0.93
# Episode 18	Average Score: 0.97
# Episode 19	Average Score: 1.01
# Episode 20	Average Score: 1.03
# Episode 21	Average Score: 1.07
# Episode 22	Average Score: 1.10
# Episode 23	Average Score: 1.13
# Episode 24	Average Score: 1.15
# Episode 25	Average Score: 1.20
# Episode 26	Average Score: 1.22
# Episode 27	Average Score: 1.25
# Episode 28	Average Score: 1.28
# Episode 29	Average Score: 1.33
# Episode 30	Average Score: 1.39
# Episode 31	Average Score: 1.42
# Episode 32	Average Score: 1.48
# Episode 33	Average Score: 1.55
# Episode 34	Average Score: 1.61
# Episode 35	Average Score: 1.71
# Episode 36	Average Score: 1.79
# Episode 37	Average Score: 1.84
# Episode 38	Average Score: 1.89
# Episode 39	Average Score: 1.98
# Episode 40	Average Score: 2.09
# Episode 41	Average Score: 2.29
# Episode 42	Average Score: 2.48
# Episode 43	Average Score: 2.70
# Episode 44	Average Score: 2.91
# Episode 45	Average Score: 3.08
# Episode 46	Average Score: 3.35
# Episode 47	Average Score: 3.56
# Episode 48	Average Score: 3.79
# Episode 49	Average Score: 4.03
# Episode 50	Average Score: 4.25
# Episode 51	Average Score: 4.39
# Episode 52	Average Score: 4.59
# Episode 53	Average Score: 4.75
# Episode 54	Average Score: 4.86
# Episode 55	Average Score: 5.07
# Episode 56	Average Score: 5.29
# Episode 57	Average Score: 5.49
# Episode 58	Average Score: 5.68
# Episode 59	Average Score: 5.93
# Episode 60	Average Score: 6.14
# Episode 61	Average Score: 6.36
# Episode 62	Average Score: 6.58
# Episode 63	Average Score: 6.81
# Episode 64	Average Score: 7.03
# Episode 65	Average Score: 7.27
# Episode 66	Average Score: 7.49
# Episode 67	Average Score: 7.71
# Episode 68	Average Score: 7.93
# Episode 69	Average Score: 8.17
# Episode 70	Average Score: 8.41
# Episode 71	Average Score: 8.65
# Episode 72	Average Score: 8.87
# Episode 73	Average Score: 9.09
# Episode 74	Average Score: 9.32
# Episode 75	Average Score: 9.56
# Episode 76	Average Score: 9.80
# Episode 77	Average Score: 10.04
# Episode 78	Average Score: 10.29
# Episode 79	Average Score: 10.56
# Episode 80	Average Score: 10.85
# Episode 81	Average Score: 11.13
# Episode 82	Average Score: 11.41
# Episode 83	Average Score: 11.69
# Episode 84	Average Score: 11.98
# Episode 85	Average Score: 12.27
# Episode 86	Average Score: 12.56
# Episode 87	Average Score: 12.85
# Episode 88	Average Score: 13.12
# Episode 89	Average Score: 13.37
# Episode 90	Average Score: 13.63
# Episode 91	Average Score: 13.89
# Episode 92	Average Score: 14.15
# Episode 93	Average Score: 14.38
# Episode 94	Average Score: 14.56
# Episode 95	Average Score: 14.76
# Episode 96	Average Score: 15.01
# Episode 97	Average Score: 15.24
# Episode 98	Average Score: 15.48
# Episode 99	Average Score: 15.71
# Episode 100	Average Score: 16.08
# Episode 101	Average Score: 16.44
# Episode 102	Average Score: 16.78
# Episode 103	Average Score: 17.15
# Episode 104	Average Score: 17.51
# Episode 105	Average Score: 17.88
# Episode 106	Average Score: 18.24
# Episode 107	Average Score: 18.61
# Episode 108	Average Score: 18.98
# Episode 109	Average Score: 19.35
# Episode 110	Average Score: 19.71
# Episode 111	Average Score: 20.08
# Episode 112	Average Score: 20.43
# Episode 113	Average Score: 20.78
# Episode 114	Average Score: 21.15
# Episode 115	Average Score: 21.51
# Episode 116	Average Score: 21.88
# Episode 117	Average Score: 22.24
# Episode 118	Average Score: 22.61
# Episode 119	Average Score: 22.96
# Episode 120	Average Score: 23.32
# Episode 121	Average Score: 23.68
# Episode 122	Average Score: 24.04
# Episode 123	Average Score: 24.40
# Episode 124	Average Score: 24.76
# Episode 125	Average Score: 25.09
# Episode 126	Average Score: 25.44
# Episode 127	Average Score: 25.78
# Episode 128	Average Score: 26.12
# Episode 129	Average Score: 26.41
# Episode 130	Average Score: 26.72
# Episode 131	Average Score: 27.03
# Episode 132	Average Score: 27.33
# Episode 133	Average Score: 27.65
# Episode 134	Average Score: 27.97
# Episode 135	Average Score: 28.29
# Episode 136	Average Score: 28.62
# Episode 137	Average Score: 28.95
# Episode 138	Average Score: 29.30
# Episode 139	Average Score: 29.62
# Episode 140	Average Score: 29.93
# Episode 141	Average Score: 30.20
#
# Environment solved in 141 episodes!	Average Score: 30.20

# %%
#plot the figure
from matplotlib import pyplot as plt
scores_avg_lst=[np.mean(i) for i in scores_lst]
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores_avg_lst)), scores_avg_lst)
plt.ylabel('Score')
plt.xlabel('Episode #')
# Out:
# Text(0.5,0,'Episode #')

# %%
######################################################################################################################

# %%
#One agent implementation below (ignore)

# %%
"""#for one agent
def reset(env):
    env_info = env.reset(train_mode=True)[brain_name] # reset the environment
    return env_info.vector_observations[0]

def step(env,action):
    env_info = env.step(action)[brain_name]       
    next_state = env_info.vector_observations[0]  
    reward = env_info.rewards[0]                  
    done = env_info.local_done[0]                 
    return next_state,reward,done


num_episodes=2000
#eps=1
#eps_decay=0.995
#eps_final=0.01
agent=DDPG()
noise=OUNoise()
scores=[]
scores_window=deque(maxlen=100)
for i in range(num_episodes+1):
    state=reset(env)
    noise.reset()
    score=0
    j=0
    agt_ctr=0
    t_step=0
    while(True):
        action=agent.act(state)
        action=noise.get_action(action,t_step)
        next_state,reward,done=step(env,action)
        agent.step(state,action,reward,next_state,done)
        state=next_state
        score+=reward
        t_step+=1
        if done:
                #eps=max(eps*eps_decay,eps_final)
                break
    scores_window.append(score) 
    scores.append(score)
    #print(score)
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(i, np.mean(scores_window)), end="")
    #if i % 100 == 0:
    print('\rEpisode {}\tAverage Score: {:.2f}'.format(i, np.mean(scores_window)))
    if np.mean(scores_window)>30.0:
        print('\nEnvironment solved in {:d} episodes!\tAverage Score: {:.2f}'.format(i-100, np.mean(scores_window)))
        #torch.save(agent.qlocal.state_dict(), 'checkpoint.pth')
        break"""
# Out:
# Episode 0	Average Score: 0.35
# Episode 1	Average Score: 0.30
# Episode 2	Average Score: 0.38
# Episode 3	Average Score: 0.57
# Episode 4	Average Score: 0.73
# Episode 5	Average Score: 0.86
# Episode 6	Average Score: 0.87
# Episode 7	Average Score: 0.80
# Episode 8	Average Score: 0.84
# Episode 9	Average Score: 0.93
# Episode 10	Average Score: 0.89
# Episode 11	Average Score: 0.87
# Episode 12	Average Score: 0.84
# Episode 13	Average Score: 0.81
# Episode 14	Average Score: 0.95
# Episode 15	Average Score: 0.91
# Episode 16	Average Score: 0.87
# Episode 17	Average Score: 0.88
# Episode 18	Average Score: 0.94
# Episode 19	Average Score: 0.94
# Episode 20	Average Score: 0.94
# Episode 21	Average Score: 0.97
# Episode 22	Average Score: 0.99
# Episode 23	Average Score: 0.97
# Episode 24	Average Score: 0.95
# Episode 25	Average Score: 0.98
# Episode 26	Average Score: 0.98
# Episode 27	Average Score: 1.00
# Episode 28	Average Score: 0.97
# Episode 29	Average Score: 0.99
# Episode 30	Average Score: 0.99
# Episode 31	Average Score: 1.02
# Episode 32	Average Score: 1.03
# Episode 33	Average Score: 1.07
# Episode 34	Average Score: 1.07
# Episode 35	Average Score: 1.05
# Episode 36	Average Score: 1.04
# Episode 37	Average Score: 1.03
# Episode 38	Average Score: 1.08
# Episode 39	Average Score: 1.08
# Episode 40	Average Score: 1.12
# Episode 41	Average Score: 1.14
# Episode 42	Average Score: 1.16
# Episode 43	Average Score: 1.14
# Episode 44	Average Score: 1.19
# Episode 45	Average Score: 1.22
# Episode 46	Average Score: 1.26
# Episode 47	Average Score: 1.30
# Episode 48	Average Score: 1.34
# Episode 49	Average Score: 1.35
# Episode 50	Average Score: 1.37
# Episode 51	Average Score: 1.44
# Episode 52	Average Score: 1.46
# Episode 53	Average Score: 1.47
# Episode 54	Average Score: 1.48
# Episode 55	Average Score: 1.52
# Episode 56	Average Score: 1.56
# Episode 57	Average Score: 1.58
# Episode 58	Average Score: 1.59
# Episode 59	Average Score: 1.59
# Episode 60	Average Score: 1.61
# Episode 61	Average Score: 1.62
# Episode 62	Average Score: 1.61
# Episode 63	Average Score: 1.61
# Episode 64	Average Score: 1.65
# Episode 65	Average Score: 1.66
# Episode 66	Average Score: 1.64
# Episode 67	Average Score: 1.70
# Episode 68	Average Score: 1.74
# Episode 69	Average Score: 1.77
# Episode 70	Average Score: 1.79
# Episode 71	Average Score: 1.85
# Episode 72	Average Score: 1.87
# Episode 73	Average Score: 1.88
# Episode 74	Average Score: 1.91
# Episode 75	Average Score: 1.95
# Episode 76	Average Score: 1.98
# Episode 77	Average Score: 2.00
# Episode 78	Average Score: 2.02
# Episode 79	Average Score: 2.03
# Episode 80	Average Score: 2.08
# Episode 81	Average Score: 2.12
# Episode 82	Average Score: 2.18
# Episode 83	Average Score: 2.24
# Episode 84	Average Score: 2.27
# Episode 85	Average Score: 2.31
# Episode 86	Average Score: 2.36
# Episode 87	Average Score: 2.41
# Episode 88	Average Score: 2.44
# Episode 89	Average Score: 2.50
# Episode 90	Average Score: 2.52
# Episode 91	Average Score: 2.55
# Episode 92	Average Score: 2.58
# Episode 93	Average Score: 2.60
# Episode 94	Average Score: 2.63
# Episode 95	Average Score: 2.65
# Episode 96	Average Score: 2.68
# Episode 97	Average Score: 2.73
# Episode 98	Average Score: 2.77
# Episode 99	Average Score: 2.80
# Episode 100	Average Score: 2.88
# Episode 101	Average Score: 2.97
# Episode 102	Average Score: 3.00
# Episode 103	Average Score: 3.04
# Episode 104	Average Score: 3.10
# Episode 105	Average Score: 3.16
# Episode 106	Average Score: 3.24
# Episode 107	Average Score: 3.30
# Episode 108	Average Score: 3.38
# Episode 109	Average Score: 3.46
# Episode 110	Average Score: 3.49
# Episode 111	Average Score: 3.57
# Episode 112	Average Score: 3.64
# Episode 113	Average Score: 3.74
# Episode 114	Average Score: 3.79
# Episode 115	Average Score: 3.84
# Episode 116	Average Score: 3.90
# Episode 117	Average Score: 3.95
# Episode 118	Average Score: 4.02
# Episode 119	Average Score: 4.11
# Episode 120	Average Score: 4.22
# Episode 121	Average Score: 4.30
# Episode 122	Average Score: 4.34
# Episode 123	Average Score: 4.43
# Episode 124	Average Score: 4.52
# Episode 125	Average Score: 4.61
# Episode 126	Average Score: 4.70
# Episode 127	Average Score: 4.80
# Episode 128	Average Score: 4.88
# Episode 129	Average Score: 5.03
# Episode 130	Average Score: 5.11
# Episode 131	Average Score: 5.17
# Episode 132	Average Score: 5.22
# Episode 133	Average Score: 5.30
# Episode 134	Average Score: 5.40
# Episode 135	Average Score: 5.49
# Episode 136	Average Score: 5.58
# Episode 137	Average Score: 5.65
# Episode 138	Average Score: 5.77
# Episode 139	Average Score: 5.90
# Episode 140	Average Score: 5.99
# Episode 141	Average Score: 6.14
# Episode 142	Average Score: 6.27
# Episode 143	Average Score: 6.41
# Episode 144	Average Score: 6.48
# Episode 145	Average Score: 6.52
# Episode 146	Average Score: 6.62
# Episode 147	Average Score: 6.76
# Episode 148	Average Score: 6.89
# Episode 149	Average Score: 7.01
# Episode 150	Average Score: 7.12
# Episode 151	Average Score: 7.18
# Episode 152	Average Score: 7.30
# Episode 153	Average Score: 7.39
# Episode 154	Average Score: 7.50
# Episode 155	Average Score: 7.60
# Episode 156	Average Score: 7.73
# Episode 157	Average Score: 7.91
# Episode 158	Average Score: 8.02
# Episode 159	Average Score: 8.15
# Episode 160	Average Score: 8.36
# Episode 161	Average Score: 8.41
# Episode 162	Average Score: 8.55
# Episode 163	Average Score: 8.74
# Episode 164	Average Score: 8.91
# Episode 165	Average Score: 9.08
# Episode 166	Average Score: 9.28
# Episode 167	Average Score: 9.42
# Episode 168	Average Score: 9.61
# Episode 169	Average Score: 9.70
# Episode 170	Average Score: 9.87
# Episode 171	Average Score: 9.99
# Episode 172	Average Score: 10.16
# Episode 173	Average Score: 10.36
# Episode 174	Average Score: 10.53
# Episode 175	Average Score: 10.73
# Episode 176	Average Score: 10.89
# Episode 177	Average Score: 11.07
# Episode 178	Average Score: 11.23
# Episode 179	Average Score: 11.37
# Episode 180	Average Score: 11.53
# Episode 181	Average Score: 11.72
# Episode 182	Average Score: 11.91
# Episode 183	Average Score: 12.09
# Episode 184	Average Score: 12.26
# Episode 185	Average Score: 12.52
# Episode 186	Average Score: 12.73
# Episode 187	Average Score: 12.86
# Episode 188	Average Score: 13.06
# Episode 189	Average Score: 13.26
# Episode 190	Average Score: 13.47
# Episode 191	Average Score: 13.67
# Episode 192	Average Score: 13.81
# Episode 193	Average Score: 13.96
# Episode 194	Average Score: 14.21
# Episode 195	Average Score: 14.45
# Episode 196	Average Score: 14.68
# Episode 197	Average Score: 14.87
# Episode 198	Average Score: 15.07
# Episode 199	Average Score: 15.30
# Episode 200	Average Score: 15.45
# Episode 201	Average Score: 15.63
# Episode 202	Average Score: 15.78
# Episode 203	Average Score: 15.94
# Episode 204	Average Score: 16.16
# Episode 205	Average Score: 16.30
# Episode 206	Average Score: 16.35
# Episode 207	Average Score: 16.46
# Episode 208	Average Score: 16.58
# Episode 209	Average Score: 16.78
# Episode 210	Average Score: 17.03
# Episode 211	Average Score: 17.13
# Episode 212	Average Score: 17.35
# Episode 213	Average Score: 17.55
# Episode 214	Average Score: 17.68
# Episode 215	Average Score: 17.86
# Episode 216	Average Score: 18.04
# Episode 217	Average Score: 18.12
# Episode 218	Average Score: 18.27
# Episode 219	Average Score: 18.44
# Episode 220	Average Score: 18.56
# Episode 221	Average Score: 18.70
# Episode 222	Average Score: 18.88
# Episode 223	Average Score: 19.09
# Episode 224	Average Score: 19.28
# Episode 225	Average Score: 19.41
# Episode 226	Average Score: 19.54
# Episode 227	Average Score: 19.69
# Episode 228	Average Score: 19.83
# Episode 229	Average Score: 19.83
# Episode 230	Average Score: 20.04
# Episode 231	Average Score: 20.23
# Episode 232	Average Score: 20.44
# Episode 233	Average Score: 20.61
# Episode 234	Average Score: 20.78
# Episode 235	Average Score: 20.92
# Episode 236	Average Score: 21.13
# Episode 237	Average Score: 21.23
# Episode 238	Average Score: 21.30
# Episode 239	Average Score: 21.40
# Episode 240	Average Score: 21.63
# Episode 241	Average Score: 21.64
# Episode 242	Average Score: 21.77
# Episode 243	Average Score: 21.82
# Episode 244	Average Score: 21.95
# Episode 245	Average Score: 22.14
# Episode 246	Average Score: 22.32
# Episode 247	Average Score: 22.28
# Episode 248	Average Score: 22.34
# Episode 249	Average Score: 22.48
# Episode 250	Average Score: 22.60
# Episode 251	Average Score: 22.77
# Episode 252	Average Score: 22.94
# Episode 253	Average Score: 23.07
# Episode 254	Average Score: 23.20
# Episode 255	Average Score: 23.33
# Episode 256	Average Score: 23.40
# Episode 257	Average Score: 23.41
# Episode 258	Average Score: 23.52
# Episode 259	Average Score: 23.55
# Episode 260	Average Score: 23.59
# Episode 261	Average Score: 23.66
# Episode 262	Average Score: 23.82
# Episode 263	Average Score: 23.94
# Episode 264	Average Score: 24.00
# Episode 265	Average Score: 23.97
# Episode 266	Average Score: 23.93
# Episode 267	Average Score: 23.99
# Episode 268	Average Score: 23.90
# Episode 269	Average Score: 23.98
# Episode 270	Average Score: 23.95
# Episode 271	Average Score: 23.98
# Episode 272	Average Score: 24.01
# Episode 273	Average Score: 23.99
# Episode 274	Average Score: 24.03
# Episode 275	Average Score: 24.00
# Episode 276	Average Score: 23.98
# Episode 277	Average Score: 23.95
# Episode 278	Average Score: 23.94
# Episode 279	Average Score: 24.00
# Episode 280	Average Score: 24.03
# Episode 281	Average Score: 24.03
# Episode 282	Average Score: 24.07
# Episode 283	Average Score: 24.00
# Episode 284	Average Score: 23.97
# Episode 285	Average Score: 23.90
# Episode 286	Average Score: 23.86
# Episode 287	Average Score: 23.85
# Episode 288	Average Score: 23.79
# Episode 289	Average Score: 23.75
# Episode 290	Average Score: 23.66
# Episode 291	Average Score: 23.66
# Episode 292	Average Score: 23.73
# Episode 293	Average Score: 23.77
# Episode 294	Average Score: 23.74
# Episode 295	Average Score: 23.72
# Episode 296	Average Score: 23.70
# Episode 297	Average Score: 23.69
# Episode 298	Average Score: 23.73
# Episode 299	Average Score: 23.65
# Episode 300	Average Score: 23.64
# Episode 301	Average Score: 23.66
# Episode 302	Average Score: 23.75
# Episode 303	Average Score: 23.73
# Episode 304	Average Score: 23.69
# Episode 305	Average Score: 23.67
# Episode 306	Average Score: 23.65
# Episode 307	Average Score: 23.73
# Episode 308	Average Score: 23.77
# Episode 309	Average Score: 23.73
# Episode 310	Average Score: 23.70
# Episode 311	Average Score: 23.72
# Episode 312	Average Score: 23.68
# Episode 313	Average Score: 23.57
# Episode 314	Average Score: 23.60
# Episode 315	Average Score: 23.56
# Episode 316	Average Score: 23.59
# Episode 317	Average Score: 23.65
# Episode 318	Average Score: 23.67
# Episode 319	Average Score: 23.62
# Episode 320	Average Score: 23.63
# Episode 321	Average Score: 23.58
# Episode 322	Average Score: 23.59
# Episode 323	Average Score: 23.49
# Episode 324	Average Score: 23.39
# Episode 325	Average Score: 23.35
# Episode 326	Average Score: 23.29
# Episode 327	Average Score: 23.23
# Episode 328	Average Score: 23.20
# Episode 329	Average Score: 23.31
# Episode 330	Average Score: 23.17
# Episode 331	Average Score: 23.15
# Episode 332	Average Score: 23.17
# Episode 333	Average Score: 23.16
# Episode 334	Average Score: 23.06
# Episode 335	Average Score: 23.09
# Episode 336	Average Score: 23.03
# Episode 337	Average Score: 23.00
# Episode 338	Average Score: 23.00
# Episode 339	Average Score: 22.94
# Episode 340	Average Score: 22.80
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-12-7688b1e80576> in <module>()
#      30         action=noise.get_action(action,t_step)
#      31         next_state,reward,done=step(env,action)
# ---> 32         agent.step(state,action,reward,next_state,done)
#      33         state=next_state
#      34         score+=reward
#
# <ipython-input-11-73ff6f55c3eb> in step(self, state, action, reward, next_state, done)
#      35             if(len(self.memory)>=BATCH_SIZE):
#      36                 experiences=self.memory.sample()
# ---> 37                 self.learn(experiences)
#      38
#      39     def act(self,state):
#
# <ipython-input-11-73ff6f55c3eb> in learn(self, experiences)
#      72         # update networks
#      73         self.optimizeractor.zero_grad()
# ---> 74         policy_loss.backward()
#      75         self.optimizeractor.step()
#      76
#
# /opt/conda/lib/python3.6/site-packages/torch/tensor.py in backward(self, gradient, retain_graph, create_graph)
#      91                 products. Defaults to ``False``.
#      92         """
# ---> 93         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#      94
#      95     def register_hook(self, hook):
#
# /opt/conda/lib/python3.6/site-packages/torch/autograd/__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#      87     Variable._execution_engine.run_backward(
#      88         tensors, grad_tensors, retain_graph, create_graph,
# ---> 89         allow_unreachable=True)  # allow_unreachable flag
#      90
#      91
#
# KeyboardInterrupt:

# %%
"""from matplotlib import pyplot as plt
fig = plt.figure()
ax = fig.add_subplot(111)
plt.plot(np.arange(len(scores)), scores)
plt.ylabel('Score')
plt.xlabel('Episode #')"""
# Out:
# Text(0.5,0,'Episode #')

# %%
# Out:
# 369
